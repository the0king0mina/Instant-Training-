# %%
# !pip install roboflow

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="lDlEcfufgIlHqz98cnfX")
project = rf.workspace("roboflow-universe-projects").project("soccer-players-ckbru")
version = project.version(16)
dataset = version.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

# %%
model = YOLO("yolo12n.pt")

# %%
results = model.train(data="/kaggle/working/Soccer-Players-16/data.yaml", epochs=100, imgsz=640)
# Out:
# Ultralytics 8.3.75 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# ...

# %%
results = model("/kaggle/working/Soccer-Players-16/test/images/USA_NED-Qatar2022_mp4-205_jpg.rf.e09e8d5474583cbdcd12a3c545e2474f.jpg")
# Out:
# image 1/1 /kaggle/working/Soccer-Players-16/test/images/USA_NED-Qatar2022_mp4-205_jpg.rf.e09e8d5474583cbdcd12a3c545e2474f.jpg: 384x640 1 Ball, 8 Players, 11.1ms
# Speed: 3.0ms preprocess, 11.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)

# %%
from ultralytics import YOLO

model = YOLO('/kaggle/working/runs/detect/train/weights/best.pt')  
results = model('/kaggle/working/Soccer-Players-16/test/images/USA_NED-Qatar2022_mp4-205_jpg.rf.e09e8d5474583cbdcd12a3c545e2474f.jpg')

for result in results:
    result.show()
# Out:
# image 1/1 /kaggle/working/Soccer-Players-16/test/images/USA_NED-Qatar2022_mp4-205_jpg.rf.e09e8d5474583cbdcd12a3c545e2474f.jpg: 384x640 1 Ball, 8 Players, 11.8ms
# Speed: 2.1ms preprocess, 11.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# <PIL.Image.Image image mode=RGB size=1920x1080>
